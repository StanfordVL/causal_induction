# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
r = np.loadtxt("rew_ppo_novf.txt")
movingmean = []
num = 100
for i in range(len(r)-num):
    movingmean.append(r[i :i+num].mean())
plt.plot(r, linestyle="", marker=",")


plt.plot(movingmean[:])
