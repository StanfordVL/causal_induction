# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
r = np.loadtxt("rew.txt")
rmean = np.cumsum(r) / np.linspace(1, len(r)+1, len(r))
plt.plot(r, linestyle="", marker=".")
plt.plot(rmean)
plt.savefig("rew.png")

# %%
# Out:
# array([-20.        , -18.99771881, -19.33023851, ..., -16.98559274,
#        -16.98487493, -16.9855977 ])
